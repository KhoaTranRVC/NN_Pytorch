# %% [markdown]
# # Introduction
#
# In this project, you will build a neural network of your own design to evaluate the CIFAR-10 dataset.
# Our target accuracy is 70%, but any accuracy over 50% is a great start.
# Some of the benchmark results on CIFAR-10 include:
#
# 78.9% Accuracy | [Deep Belief Networks; Krizhevsky, 2010](https://www.cs.toronto.edu/~kriz/conv-cifar10-aug2010.pdf)
#
# 90.6% Accuracy | [Maxout Networks; Goodfellow et al., 2013](https://arxiv.org/pdf/1302.4389.pdf)
#
# 96.0% Accuracy | [Wide Residual Networks; Zagoruyko et al., 2016](https://arxiv.org/pdf/1605.07146.pdf)
#
# 99.0% Accuracy | [GPipe; Huang et al., 2018](https://arxiv.org/pdf/1811.06965.pdf)
#
# 98.5% Accuracy | [Rethinking Recurrent Neural Networks and other Improvements for ImageClassification; Nguyen et al., 2020](https://arxiv.org/pdf/2007.15161.pdf)
#
# Research with this dataset is ongoing. Notably, many of these networks are quite large and quite expensive to train.
#
# ## Imports

# %%
## This cell contains the essential imports you will need – DO NOT CHANGE THE CONTENTS! ##
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load the Dataset
#
# Specify your transforms as a list first.
# The transforms module is already loaded as `transforms`.
#
# CIFAR-10 is fortunately included in the torchvision module.
# Then, you can create your dataset using the `CIFAR10` object from `torchvision.datasets` ([the documentation is available here](https://pytorch.org/docs/stable/torchvision/datasets.html#cifar)).
# Make sure to specify `download=True`!
#
# Once your dataset is created, you'll also need to define a `DataLoader` from the `torch.utils.data` module for both the train and the test set.

# %%
# Define transforms
# A common strategy for training neural networks is to introduce randomness in the input data itself. For example, you can randomly rotate, mirror, scale, and/or crop your images during training.
# This will help your network generalize as it's seeing the same images but in different locations, with different sizes, in different orientations, etc.
## YOUR CODE HERE ##
train_transform = transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(32),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.ToTensor()
])

# Create training set and define training dataloader
## YOUR CODE HERE ##
train_data = torchvision.datasets.CIFAR10('CIFAR10/', download=True, train=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)

# Create test set and define test dataloader
## YOUR CODE HERE ##
test_data = torchvision.datasets.CIFAR10('CIFAR10/', download=True, train=False, transform=test_transform)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32)

# The 10 classes in the dataset
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Explore the Dataset
# Using matplotlib, numpy, and torch, explore the dimensions of your data.
#
# You can view images using the `show5` function defined below – it takes a data loader as an argument.
# Remember that normalized images will look really weird to you! You may want to try changing your transforms to view images.
# Typically using no transforms other than `toTensor()` works well for viewing – but not as well for training your network.
# If `show5` doesn't work, go back and check your code for creating your data loaders and your training/test sets.

# %%
def show5(img_loader):
    dataiter = iter(img_loader)
    
    batch = next(dataiter)
    labels = batch[1][0:5]
    images = batch[0][0:5]
    for i in range(5):
        print(classes[labels[i]])
    
        image = images[i].numpy()
        plt.imshow(image.T)
        plt.show()

# %%
# Explore data
## YOUR CODE HERE ##
show5(trainloader)
show5(testloader)
# Out:
# car
# cat
# ship
# plane
# car
# cat
# ship
# ship
# plane
# frog

# %% [markdown]
# ## Build your Neural Network
# Using the layers in `torch.nn` (which has been imported as `nn`) and the `torch.nn.functional` module (imported as `F`), construct a neural network based on the parameters of the dataset.
# Feel free to construct a model of any architecture – feedforward, convolutional, or even something more advanced!

# %%
## YOUR CODE HERE ##
class Classifier(nn.Module):
  def __init__(self):
    super().__init__()

    self.fc1 = nn.Linear(3*32*32, 64)
    self.fc2 = nn.Linear(64, 32)
    self.fc3 = nn.Linear(32, 10)

    self.logsoftmax = nn.LogSoftmax(dim=1)

  def forward(self, x):
    x = x.view(x.shape[0], -1)

    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.logsoftmax(self.fc3(x))

    return x

# %% [markdown]
# Specify a loss function and an optimizer, and instantiate the model.
#
# If you use a less common loss function, please note why you chose that loss function in a comment.

# %%
## YOUR CODE HERE ##
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.003, momentum=0.9)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Classifier(
#   (fc1): Linear(in_features=3072, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %% [markdown]
# ## Running your Neural Network
# Use whatever method you like to train your neural network, and ensure you record the average loss at each epoch.
# Don't forget to use `torch.device()` and the `.to()` method for both your model and your data if you are using GPU!
#
# If you want to print your loss during each epoch, you can use the `enumerate` function and print the loss after a set number of batches. 250 batches works well for most people!

# %%
## YOUR CODE HERE ##
epochs = 10
steps = 0
running_loss = 0
print_every = 200
train_losses, test_losses = [], []
accuracies = []

for epoch in range(epochs):
    for inputs, labels in trainloader:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in testloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    test_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(testloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(testloader):.3f}")
            
            train_losses.append(running_loss/print_every)
            test_losses.append(test_loss/len(testloader))
            accuracies.append(accuracy/len(testloader))
            running_loss = 0
            model.train()
# Out:
# Epoch 1/10.. Train loss: 1.745.. Test loss: 1.572.. Test accuracy: 0.438
# Epoch 1/10.. Train loss: 1.730.. Test loss: 1.567.. Test accuracy: 0.440
# Epoch 1/10.. Train loss: 1.739.. Test loss: 1.572.. Test accuracy: 0.441
# Epoch 1/10.. Train loss: 1.734.. Test loss: 1.554.. Test accuracy: 0.455
# Epoch 1/10.. Train loss: 1.751.. Test loss: 1.551.. Test accuracy: 0.454
# Epoch 1/10.. Train loss: 1.741.. Test loss: 1.524.. Test accuracy: 0.461
# Epoch 1/10.. Train loss: 1.746.. Test loss: 1.560.. Test accuracy: 0.449
# Epoch 2/10.. Train loss: 1.753.. Test loss: 1.535.. Test accuracy: 0.454
# Epoch 2/10.. Train loss: 1.737.. Test loss: 1.578.. Test accuracy: 0.437
# Epoch 2/10.. Train loss: 1.727.. Test loss: 1.529.. Test accuracy: 0.455
# Epoch 2/10.. Train loss: 1.732.. Test loss: 1.526.. Test accuracy: 0.462
# Epoch 2/10.. Train loss: 1.742.. Test loss: 1.520.. Test accuracy: 0.465
# Epoch 2/10.. Train loss: 1.738.. Test loss: 1.532.. Test accuracy: 0.463
# Epoch 2/10.. Train loss: 1.762.. Test loss: 1.524.. Test accuracy: 0.458
# Epoch 2/10.. Train loss: 1.757.. Test loss: 1.570.. Test accuracy: 0.444
# Epoch 3/10.. Train loss: 1.716.. Test loss: 1.516.. Test accuracy: 0.458
# Epoch 3/10.. Train loss: 1.740.. Test loss: 1.559.. Test accuracy: 0.447
# Epoch 3/10.. Train loss: 1.744.. Test loss: 1.546.. Test accuracy: 0.450
# Epoch 3/10.. Train loss: 1.731.. Test loss: 1.531.. Test accuracy: 0.454
# Epoch 3/10.. Train loss: 1.739.. Test loss: 1.587.. Test accuracy: 0.431
# Epoch 3/10.. Train loss: 1.738.. Test loss: 1.551.. Test accuracy: 0.448
# Epoch 3/10.. Train loss: 1.749.. Test loss: 1.543.. Test accuracy: 0.455
# Epoch 3/10.. Train loss: 1.734.. Test loss: 1.529.. Test accuracy: 0.463
# Epoch 4/10.. Train loss: 1.729.. Test loss: 1.524.. Test accuracy: 0.464
# Epoch 4/10.. Train loss: 1.753.. Test loss: 1.542.. Test accuracy: 0.460
# Epoch 4/10.. Train loss: 1.716.. Test loss: 1.536.. Test accuracy: 0.449
# Epoch 4/10.. Train loss: 1.745.. Test loss: 1.542.. Test accuracy: 0.458
# Epoch 4/10.. Train loss: 1.744.. Test loss: 1.571.. Test accuracy: 0.443
# Epoch 4/10.. Train loss: 1.743.. Test loss: 1.535.. Test accuracy: 0.455
# Epoch 4/10.. Train loss: 1.739.. Test loss: 1.524.. Test accuracy: 0.457
# Epoch 4/10.. Train loss: 1.730.. Test loss: 1.536.. Test accuracy: 0.455
# Epoch 5/10.. Train loss: 1.756.. Test loss: 1.525.. Test accuracy: 0.462
# Epoch 5/10.. Train loss: 1.726.. Test loss: 1.534.. Test accuracy: 0.455
# Epoch 5/10.. Train loss: 1.747.. Test loss: 1.564.. Test accuracy: 0.439
# Epoch 5/10.. Train loss: 1.729.. Test loss: 1.552.. Test accuracy: 0.444
# Epoch 5/10.. Train loss: 1.735.. Test loss: 1.512.. Test accuracy: 0.462
# Epoch 5/10.. Train loss: 1.732.. Test loss: 1.541.. Test accuracy: 0.450
# Epoch 5/10.. Train loss: 1.713.. Test loss: 1.565.. Test accuracy: 0.442
# Epoch 5/10.. Train loss: 1.753.. Test loss: 1.559.. Test accuracy: 0.450
# Epoch 6/10.. Train loss: 1.745.. Test loss: 1.542.. Test accuracy: 0.460
# Epoch 6/10.. Train loss: 1.749.. Test loss: 1.568.. Test accuracy: 0.444
# Epoch 6/10.. Train loss: 1.739.. Test loss: 1.555.. Test accuracy: 0.450
# Epoch 6/10.. Train loss: 1.733.. Test loss: 1.571.. Test accuracy: 0.450
# Epoch 6/10.. Train loss: 1.722.. Test loss: 1.536.. Test accuracy: 0.460
# Epoch 6/10.. Train loss: 1.745.. Test loss: 1.544.. Test accuracy: 0.458
# Epoch 6/10.. Train loss: 1.729.. Test loss: 1.530.. Test accuracy: 0.456
# Epoch 7/10.. Train loss: 1.733.. Test loss: 1.569.. Test accuracy: 0.452
# Epoch 7/10.. Train loss: 1.745.. Test loss: 1.568.. Test accuracy: 0.450
# Epoch 7/10.. Train loss: 1.739.. Test loss: 1.530.. Test accuracy: 0.452
# Epoch 7/10.. Train loss: 1.760.. Test loss: 1.517.. Test accuracy: 0.466
# Epoch 7/10.. Train loss: 1.717.. Test loss: 1.520.. Test accuracy: 0.458
# Epoch 7/10.. Train loss: 1.747.. Test loss: 1.550.. Test accuracy: 0.449
# Epoch 7/10.. Train loss: 1.724.. Test loss: 1.545.. Test accuracy: 0.448
# Epoch 7/10.. Train loss: 1.723.. Test loss: 1.540.. Test accuracy: 0.459
# Epoch 8/10.. Train loss: 1.731.. Test loss: 1.506.. Test accuracy: 0.475
# Epoch 8/10.. Train loss: 1.737.. Test loss: 1.549.. Test accuracy: 0.447
# Epoch 8/10.. Train loss: 1.741.. Test loss: 1.551.. Test accuracy: 0.453
# Epoch 8/10.. Train loss: 1.739.. Test loss: 1.586.. Test accuracy: 0.434
# Epoch 8/10.. Train loss: 1.721.. Test loss: 1.539.. Test accuracy: 0.451
# Epoch 8/10.. Train loss: 1.728.. Test loss: 1.543.. Test accuracy: 0.455
# Epoch 8/10.. Train loss: 1.759.. Test loss: 1.535.. Test accuracy: 0.451
# Epoch 8/10.. Train loss: 1.718.. Test loss: 1.556.. Test accuracy: 0.446
# Epoch 9/10.. Train loss: 1.718.. Test loss: 1.549.. Test accuracy: 0.453
# Epoch 9/10.. Train loss: 1.720.. Test loss: 1.530.. Test accuracy: 0.459
# Epoch 9/10.. Train loss: 1.730.. Test loss: 1.553.. Test accuracy: 0.450
# Epoch 9/10.. Train loss: 1.731.. Test loss: 1.552.. Test accuracy: 0.443
# Epoch 9/10.. Train loss: 1.745.. Test loss: 1.547.. Test accuracy: 0.456
# Epoch 9/10.. Train loss: 1.753.. Test loss: 1.536.. Test accuracy: 0.457
# Epoch 9/10.. Train loss: 1.708.. Test loss: 1.502.. Test accuracy: 0.469
# Epoch 9/10.. Train loss: 1.743.. Test loss: 1.553.. Test accuracy: 0.456
# Epoch 10/10.. Train loss: 1.749.. Test loss: 1.560.. Test accuracy: 0.440
# Epoch 10/10.. Train loss: 1.722.. Test loss: 1.537.. Test accuracy: 0.447
# Epoch 10/10.. Train loss: 1.723.. Test loss: 1.538.. Test accuracy: 0.457
# Epoch 10/10.. Train loss: 1.734.. Test loss: 1.538.. Test accuracy: 0.453
# Epoch 10/10.. Train loss: 1.738.. Test loss: 1.541.. Test accuracy: 0.451
# Epoch 10/10.. Train loss: 1.711.. Test loss: 1.563.. Test accuracy: 0.448
# Epoch 10/10.. Train loss: 1.731.. Test loss: 1.557.. Test accuracy: 0.449
# Epoch 10/10.. Train loss: 1.729.. Test loss: 1.547.. Test accuracy: 0.455

# %% [markdown]
# Plot the training loss (and validation loss/accuracy, if recorded).

# %%
## YOUR CODE HERE ##
# %matplotlib inline
# %config inlineBackend.figure_format='retina'

import matplotlib.pyplot as plt
plt.plot(train_losses,label='Train loss')
plt.plot(test_losses,label='Validation loss')
plt.legend()
plt.show()

plt.plot(accuracies,label='Validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing your model
# Using the previously created `DataLoader` for the test set, compute the percentage of correct predictions using the highest probability prediction.
#
# If your accuracy is over 70%, great work!
# This is a hard task to exceed 70% on.
#
# If your accuracy is under 45%, you'll need to make improvements.
# Go back and check your model architecture, loss function, and optimizer to make sure they're appropriate for an image classification task.

# %%
## YOUR CODE HERE ##
accuracy = 0
model.eval()
with torch.no_grad():
  for images, labels in testloader:
    images = images.to(device)
    labels = labels.to(device)
    logps = model.forward(images)

    ps = torch.exp(logps)
    top_p, top_class = ps.topk(1, dim=1)
    equality = top_class == labels.view(*top_class.shape)
    accuracy += torch.mean(equality.type(torch.FloatTensor)).item()
model.train()
print(f"Test accuracy: {accuracy/len(testloader):.4%}")
# Out:
# Test accuracy: 45.7368%

# %% [markdown]
# ## Saving your model
# Using `torch.save`, save your model for future loading.

# %%
## YOUR CODE HERE ##
checkpoint = {'state_dict': model.state_dict(),
            'optimizer': optimizer,
            'criterion': criterion,
            'accuracies':accuracies,
            'train_losses':train_losses,
            'validation_losses': accuracy,
            'model': model}
torch.save(checkpoint, 'model.pth')

# %% [markdown]
# ## Make a Recommendation
#
# Based on your evaluation, what is your recommendation on whether to build or buy? Explain your reasoning below.

# %% [markdown]
# **Double click this cell to modify it**
# - This model is just simple, it is reasonable for someone to get start for how to build Neuron network with Pytorch
# - Accuracy is around 45%, but it can be improved by increasing the epoch in training session
# - For more convenience, should use GPU to accelerate the training time
